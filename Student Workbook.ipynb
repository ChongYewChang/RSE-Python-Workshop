# %% [markdown]
# <img src = "http://www.realskills.me/images/realskills.jpg"></img>
# ## Introduction to Programming, Python for everyday applications
#
# <img src = "https://static.makeuseof.com/wp-content/uploads/2018/03/python-faq-670x335.jpg"></img>

# %% [markdown]
# # Your First Python Program
#
# The print() function prints the specified message to the screen, or other standard output device.

# %%
print()

# %% [markdown]
# # Python Object and Data Structure Basics
#
# - Numbers
# - Variables
# - Strings
# - Lists
# - Dictionaries

# %%
# Addition
2+1
7+10
# Out:
# 17

# %%
# Subtraction
2-1

# %%
# Multiplication
2*2

# %%
# Division
3/2

# %%
# Floor Division
7//4
# Out:
# 1

# %%
# Modulo
7%4

# %%
# Powers
2**3
# Out:
# 8

# %% [markdown]
# ## Variable Assignments
#
# Now that we've seen how to use numbers in Python as a calculator let's see how we can assign names and create variables.
#
# We use a single equals sign to assign labels to variables. Let's see a few examples of how we can do this.

# %%
# Let's create an object called "a" and assign it the number 5
a = 5

# %% [markdown]
# Now if I call *a* in my Python script, Python will treat it as the number 5.

# %%
# Adding the objects
a+a

# %% [markdown]
# What happens on reassignment? Will Python let us write it over?

# %%
a = 15

# %%
print(a)
# Out:
# 5

# %% [markdown]
# Yes! Python allows you to write over assigned variable names. We can also use the variables themselves when doing the reassignment. Here is an example of what I mean:

# %%
a = 10

# %%
a = a + a

# %% [markdown]
# ## Variables
# The names you use when creating these labels need to follow a few rules:
#
#     1. Names can not start with a number.
#     2. There can be no spaces in the name, use _ instead.
#     3. Can't use any of these symbols :'",<>/?|\()!@#$%^&*~-+
#     4. It's considered best practice (PEP8) that names are lowercase.
#     5. Avoid using the characters 'l' (lowercase letter el), 'O' (uppercase letter oh),
#        or 'I' (uppercase letter eye) as single character variable names.
#     6. Avoid using words that have special meaning in Python like "list" and "str"
#
#
# Using variable names can be a very useful way to keep track of different variables in Python. For example:

# %% [markdown]
# ## Exercise - Simple interest calculator
#
# How would I form an expression to find the simple interest of $10000 at 5% rate for 2 years?

# %%
# enter your exercise solution here

# %% [markdown]
# # Strings

# %% [markdown]
# Strings are used in Python to record text information, such as names.
#
# Strings in Python are actually a sequence, which basically means Python keeps track of every element in the string as a sequence. For example, Python understands the string "hello' to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter, or the last letter).

# %% [markdown]
# ## Creating a String
# To create a string in Python you need to use either single quotes or double quotes. For example:

# %%
# Single word
'hello'
# Out:
# 'hello'

# %%
# Entire phrase 
'This is also a string'
# Out:
# 'This is also a string'

# %%
# We can also use double quote
"String built with double quotes"

# %%
# Be careful with quotes!
' I'm using single quotes, but this will create an error'
# Out:
#   File "<ipython-input-19-da9a34b3dc31>", line 2
#     ' I'm using single quotes, but this will create an error'
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# The reason for the error above is because the single quote in I'm stopped the string. You can use combinations of double and single quotes to get the complete statement.

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %% [markdown]
# ## String Basics

# %% [markdown]
# We can also use a function called len() to check the length of a string!

# %%
len('Hello World')
# Out:
# 11

# %% [markdown]
# ## String Indexing
# We know strings are a sequence, which means Python can use indexes to call parts of the sequence. Let's learn how this works.
#
# In Python, we use brackets <code>[]</code> after an object to call its index. We should also note that indexing starts at 0 for Python. Let's create a new object called <code>s</code> and then walk through a few examples of indexing.

# %%
# assign s to a string
s = "Hello World"
# print the first letter in s
print(s[0])
# print the second letter in s
print(s[1])

# %% [markdown]
# ## String Properties
# It's important to note that strings have an important property known as *immutability*. This means that once a string is created, the elements within it can not be changed or replaced. For example:

# %%
s[2] = "n"
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-fe9f6f1044b1> in <module>()
# ----> 1 s[2] = "n"
#       2 print(s)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Notice how the error tells us directly what we can't do, change the item assignment!
#
# Something we *can* do is concatenate strings!

# %%
s + " what's up"
# Out:
# "Hello World what's up"

# %% [markdown]
# ## Basic Built-in String methods
#
# Objects in Python usually have built-in methods. These methods are functions inside the object (we will learn about these in much more depth later) that can perform actions or commands on the object itself.
#
# We call methods with a period and then the method name. Methods are in the form:
#
# object.method(parameters)
#
# Where parameters are extra arguments we can pass into the method. Don't worry if the details don't make 100% sense right now. Later on we will be creating our own objects and functions!
#
# Here are some examples of built-in methods in strings:

# %%
# Upper Case a string
s.upper()
# Out:
# 'HELLO WORLD'

# %%
# Lower case for a string
s.lower()
# Out:
# 'hello world'

# %% [markdown]
# ## Print Formatting
#
# We can use the f"" & {} syntax to add formatted objects to printed string statements.
#
# This is very useful if we need to use variables in our strings or if we need to concatenate numbers with strings

# %%
age = 20
msg = f"I am {age} years old"
print(msg)
# Out:
# 'I am 20 years old'

# %%
# Why doesnt this work?
age = 20
msg = "I am " + age + " years old"
print(msg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-b99e603d3bcc> in <module>()
#       1 age = 20
# ----> 2 msg = "I am " + age + " years old"
#       3 print(msg)
#
# TypeError: must be str, not int

# %%
#The input() function allows user input.
age = input("How old are you?\n")
print(age)
# Out:
# How old are you?
# 10
# 10

# %% [markdown]
# ## Exercise - Simple Arithmetic
#
# A user inputs their age and the program will tell you what year you will turn 100

# %%
# Enter your exercise solution here

# %% [markdown]
# ## Lists
#
# Earlier when discussing strings we introduced the concept of a *sequence* in Python.
#
# Lists can be thought of the most general version of a *sequence* in Python. Unlike strings, they are mutable, meaning the elements inside a list can be changed!
#
# Lists are constructed with brackets [] and commas separating every element in the list.
#
# There are also special types of lists called tuples which are defined by ()
#
# Let's go ahead and see how we can construct lists!

# %%
# Assign a list to an variable named my_list
my_list = [1,2,3]

# %% [markdown]
# We just created a list of integers, but lists can actually hold different object types. For example:

# %%
my_list = ['A string',23,100.232,'o']

# %% [markdown]
# ### Indexing and Slicing
# Indexing and slicing work just like in strings. Let's make a new list to remind ourselves of how this works:

# %%
my_list = ['one','two','three',4,5]

# %%
# Grab element at index 0
my_list[0]
# Out:
# 'one'

# %% [markdown]
# We can also use + to concatenate lists, just like we did for strings.

# %%
my_list + ['new item']
# Out:
# ['one', 'two', 'three', 4, 5, 'new item']

# %% [markdown]
# Note: This doesn't actually change the original list!

# %%
my_list
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
# Reassign
my_list = my_list + ['add new item permanently']

# %% [markdown]
# ## List Properties

# %% [markdown]
# If you are familiar with another programming language, you might start to draw parallels between arrays in another language and lists in Python. Lists in Python however, tend to be more flexible than arrays in other languages for a two good reasons: they have no fixed size (meaning we don't have to specify how big a list will be), and they have no fixed type constraint (like we've seen above).
#
# Let's go ahead and explore some more special methods for lists:

# %%
# Create a new list
list1 = [1,2,3]

# %%
# Append
list1.append('append me!')

# %%
# Show
list1
# Out:
# [1, 2, 3, 'append me!']

# %% [markdown]
# Use pop to "pop off" an item from the list. By default pop takes off the last index, but you can also specify which index to pop off. Let's see an example:

# %%
# Pop off the 0 indexed item
list1.pop(0)
# Out:
# 1

# %%
# Show
list1
# Out:
# [2, 3, 'append me!']

# %%
# Assign the popped element, remember default popped index is -1
# wont work if list has no elements
popped_item = list1.pop()

# %% [markdown]
# It should also be noted that lists indexing will return an error if there is no element at that index. For example:

# %%
list1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-af6d2015fa1f> in <module>()
# ----> 1 list1[100]
#
# IndexError: list index out of range

# %%
# Python data structures support "nesting" e.g list of lists
# Let's make three lists
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,8,9]

# Make a list of lists to form a matrix
matrix = [lst_1,lst_2,lst_3]
print(matrix)
# get first column
print(matrix[0])
# get specific index
print(matrix[0][0])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# [1, 2, 3]
# 1

# %% [markdown]
# # Python Comparison Operators and Statements
#
# - Boolean logic, True/False
# - Comparison Operators, if,else, elif

# %% [markdown]
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td>(a != b) is true</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %% [markdown]
# if Statements in Python allows us to tell the computer to perform alternative actions based on a certain set of results.
#
# Verbally, we can imagine we are telling the computer:
#
# "Hey if this case happens, perform some action"
#
# We can then expand the idea further with elif and else statements, which allow us to tell the computer:
#
# "Hey if this case happens, perform some action. Else, if another case happens, perform some other action. Else, if none of the above cases happened, perform this action."
#
# Let's go ahead and look at the syntax format for if statements to get a better idea of this:

# %%
person = 'George'

if person == 'Sammy':
    print('Welcome Sammy!')
elif person =='George':
    print('Welcome George!')
else:
    print("Welcome, what's your name?")
# Out:
# Welcome George!

# %% [markdown]
# ## Exercise - Bar Entry
#
# Write a program that "prints" if you are able to enter a bar (yes "otherwise" no) if you "input" your birth year
#
# - Assume age restriction for entry is 18

# %%
# Enter your solution to the exercise here

# %% [markdown]
# # for Loops
#
# A <code>for</code> loop acts as an iterator in Python; it goes through items that are in a *sequence* or any other iterable item. Objects that we've learned about that we can iterate over include strings, lists, tuples, and even built-in iterables for dictionaries, such as keys or values.
#
# We've already seen the <code>for</code> statement a little bit in past lectures but now let's formalize our understanding.
#
# Here's the general format for a <code>for</code> loop in Python:
#
#     for item in object:
#         statements to do stuff

# %%
list1 = [1,2,3,4,5,6]
for item in list1:
    print(item)

# %% [markdown]
# ## Exercise FizzBuzz
#
# Write a program that "inputs" in 1 number and prints it
#
# But for multiples of three print “Fizz” instead of the number and for the multiples of five print “Buzz”.
#
# For numbers which are multiples of both three and five print “FizzBuzz”."

# %%
# Enter your solution to the exercise here

# %% [markdown]
# # Dictionaries
#
# A dictionary is a collection which is unordered, changeable and indexed. In Python dictionaries are written with curly brackets, and they have keys and values.

# %%
# define a dictionary with {}
my_dict = {"hi":"there"}
my_dict["hi"]
# Out:
# 'there'

# %%
# insert a new key
my_dict["key"] = "value"

# %%
# dictionaries are mutable so adding a key changes the dictionary
print(my_dict)
# Out:
# {'hi': 'there', 'key': 'value'}

# %%
# prints keys
for x in my_dict.keys():
    print(x)

# print keys and values -> remember that .items() returns a tuple
for key,value in my_dict.items():
    print(key,value)
# Out:
# hi
# key
# hi there
# key value

# %% [markdown]
# ## Exercise - Dictionary Challenge
#
# Using the dictionary provided "test_dict" print the string "You did it" by indexing the dictionary

# %%
# enter your solution to the exercise here
# dictionary values can also be lists, numbers and even other dictionaries
test_dict = {"a":"hello world","test":"test","awesome":{"trick":"what","job":[1,2,3,4,5,6,"You did it!"]}}

# %% [markdown]
# # Exercise - Timetable planner
#
# A course code has a list of lectures and tutorials
#
# User inputs the index to choose a lecture, tutorial and lab if neccesary
#
# When the user has finished for all classes print the complete timetable
#
#
# for example if a student picks 'ACC501'
#
# <code>[('Accounting & Financial Mgt 1A', 'LEC', 'A', 'Tue 16-18 (w11, Science Th); Thu 16-18 (w1-9, Science Th)'), ('Accounting & Financial Mgt 1A', 'LEC', 'B', 'Wed 09-11 (w1-10, Science Th)'), ('Accounting & Financial Mgt 1A', 'LEC', 'C', 'Wed 09-11 (w11, CLB 7); Fri 09-11 (w1-8,10, CLB 7)'), ('Accounting & Financial Mgt 1A', 'LEC', 'D', 'Tue 13-15 (w11, PhysicsTh); Thu 13-15 (w1-9, PhysicsTh)'), ('Accounting & Financial Mgt 1A', 'LEC', 'E', 'Wed 12-14 (w11, PhysicsTh); Fri 12-14 (w1-8,10, PhysicsTh)')</code>
#
# To pick a lecture you would enter 0 as in integer as the lecture is the first index of the list

# %%
import pickle
# Dont worry about this
# File I/O
with open("timetable.pickle","rb") as pickle_in:
    # treat offerings as a dictionary
    offerings = pickle.load(pickle_in)
print(offerings)
# Out:
# defaultdict(<class 'list'>, {'ACC501': [('Accounting & Financial Mgt 1A', 'LEC', 'A', 'Tue 16-18 (w11, Science Th); Thu 16-18 (w1-9, Science Th)'), ('Accounting & Financial Mgt 1A', 'LEC', 'B', 'Wed 09-11 (w1-10, Science Th)'), ('Accounting & Financial Mgt 1A', 'LEC', 'C', 'Wed 09-11 (w11, CLB 7); Fri 09-11 (w1-8,10, CLB 7)'), ('Accounting & Financial Mgt 1A', 'LEC', 'D', 'Tue 13-15 (w11, PhysicsTh); Thu 13-15 (w1-9, PhysicsTh)'), ('Accounting & Financial Mgt 1A', 'LEC', 'E', 'Wed 12-14 (w11, PhysicsTh); Fri 12-14 (w1-8,10, PhysicsTh)'), ('Accounting & Financial Mgt 1A', 'TUT', 'F09A', 'Wed 09-10:30 (w11, Gold G07); Fri 09-10:30 (w2-8,10, Gold G07)'), ('Accounting & Financial Mgt 1A', 'TUT', 'F09B', 'Wed 09-10:30 (w11, Sqhouse215); Fri 09-10:30 (w2-8,10, Sqhouse215)'), ('Accounting & Financial Mgt 1A', 'TUT', 'F10A', 'Wed 10:30-12 (w11, Gold G07); Fri 10:30-12 (w2-8,10, Gold G07)'), ('Accounting & Financial Mgt 1A', 'TUT', 'F10B', 'Wed 10:30-12 (w11, Sqhouse215); Fri 10:30-12 (w2-8,1
# ...

# %%
# we can check if a course is offered in trimester 1

# replace ACC501 with your own course
course = "ACC501"
if course in offerings:
    print("course is offered")
else:
    print("course is not offered")

# %%
# Enter Courses -> prompt the user to input their courses
# if you are not a UNSW student please input the courses, COMP3121, COMP3231, COMP4337
course1 = ?
course2 = ?
course3 = ?
# Out:
#   File "<ipython-input-68-bbbd844cb600>", line 3
#     course1 = ?
#               ^
# SyntaxError: invalid syntax

# %%
# Store all our courses in 1 list for easy access and reference
semester = ?
# we need a dictionary to store our choices for class times how do we do that?
enrollment = ?
# Out:
#   File "<ipython-input-64-d0f3f58c375f>", line 2
#     semester = ?
#                ^
# SyntaxError: invalid syntax

# %%
# iterate over all the courses you entered
for course in semester:
    # get your specific course details from "offerings" using "course" as a key
    course_choices = ?
    # print out all the classes in your course
    for index,classes in enumerate(course_choices):
        print(index,classes)
    # enter a choice for your tutorial and lecture, this needs to be entered as a number to index course_choices list
    tutorial = ?
    lecture = ?
    #lab = int(input("Please enter your lab\n"))
    
    # Using tutorial & lectures (which are integers) select an index in course_choices as a tutorial or lecture
    enrollment[course] = "lecture:\n" + ? 
    + "\n" + "tutorial:\n" + ?
# Out:
#   File "<ipython-input-65-7c6d57a0f05d>", line 4
#     course_choices = ?
#                      ^
# SyntaxError: invalid syntax

# %%
# print our course timetable

# %% [markdown]
# # CONGRATS WE'RE DONE YOU'RE AWESOME
